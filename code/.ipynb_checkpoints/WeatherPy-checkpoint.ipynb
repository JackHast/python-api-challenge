# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from pprint import pprint
# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
base_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = base_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    response = requests.get(city_url)
    
    try:
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila velha
# Processing Record 2 of Set 1 | west island
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | prado
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | nemuro
# Processing Record 11 of Set 1 | kailua-kona
# Processing Record 12 of Set 1 | chernyshevskiy
# Processing Record 13 of Set 1 | isangel
# Processing Record 14 of Set 1 | katabu
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hawaiian paradise park
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | tayshet
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | waitangi
# Processing Record 21 of Set 1 | port mathurin
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      vila velha -20.3297  -40.2925     17.75        94          53
# 1     west island -12.1568   96.8225     25.99        78          75
# 2  margaret river -33.9500  115.0667     16.03        62          18
# 3       carnarvon -24.8667  113.6333     23.20        23           0
# 4       adamstown -25.0660 -130.1015     20.85        68          39
#
#    Wind Speed Country        Date
# 0        1.34      BR  1690005725
# 1        7.20      CC  1690005726
# 2        3.50      AU  1690005727
# 3        8.63      AU  1690005608
# 4       11.81      PN  1690005728

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            vila velha -20.3297  -40.2925     17.75        94          53
# 1           west island -12.1568   96.8225     25.99        78          75
# 2        margaret river -33.9500  115.0667     16.03        62          18
# 3             carnarvon -24.8667  113.6333     23.20        23           0
# 4             adamstown -25.0660 -130.1015     20.85        68          39
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      BR  1690005725
# 1              7.20      CC  1690005726
# 2              3.50      AU  1690005727
# 3              8.63      AU  1690005608
# 4             11.81      PN  1690005728

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Temperature')
plt.grid()


# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linregress(hemisphere,set_name_1,set_name_2,data_set_1,data_set_2):
    (slope, inter, r, p, std_err) = stats.linregress(data_set_1,data_set_2)
    fit = data_set_1*slope + inter
    plt.scatter(data_set_1,data_set_2)
    plt.plot(data_set_1,fit,color="red")
    plt.xlabel(set_name_1)
    plt.ylabel(set_name_2)
    plt.title('')
    print(f"The r-value is: {round(r,2)}")
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(inter,2))
    plt.annotate(line_eq,(20,5),fontsize=15,color="red")
    if hemisphere == 'North':
        plt.annotate(line_eq,(20,5),fontsize=15,color="red")
    else:
        plt.annotate(line_eq,(-25,30),fontsize=15,color="red")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df['Lat']>=0),:]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 9                        nemuro  43.3236  145.5750     16.71        90
# 10                  kailua-kona  19.6406 -155.9956     27.98        86
# 11               chernyshevskiy  63.0128  112.4714     29.63        29
# 14                       albany  42.6001  -73.9662     18.48        92
# 15       hawaiian paradise park  19.5933 -154.9731     24.85        94
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 9                24        6.43      JP  1690005616
# 10              100        6.69      US  1690005732
# 11               18        3.94      RU  1690005733
# 14                1        2.87      US  1690005735
# 15               41        1.68      US  1690005736

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df['Lat']<0),:]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            vila velha -20.3297  -40.2925     17.75        94          53
# 1           west island -12.1568   96.8225     25.99        78          75
# 2        margaret river -33.9500  115.0667     16.03        62          18
# 3             carnarvon -24.8667  113.6333     23.20        23           0
# 4             adamstown -25.0660 -130.1015     20.85        68          39
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      BR  1690005725
# 1              7.20      CC  1690005726
# 2              3.50      AU  1690005727
# 3              8.63      AU  1690005608
# 4             11.81      PN  1690005728

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linregress('North','Latitude','Temperature',northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
# Out:
# The r-value is: -0.56

# %%
# Linear regression on Southern Hemisphere
linregress('South','Latitude','Temperature',southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
# Out:
# The r-value is: 0.8

# %% [markdown]
# **Discussion about the linear relationship:** For the northern hemisphere there is a moderate negative correlation between latitude and max temperature and for the southern hemisphere there is a strong positive correlation between latitude and max temperature. Though relationship for the southern hemisphere seems to be linear for the northern hemisphere the greatest temperatures appear to be at a latitude of about 20-40 and so maybe the relationship is more parabolic.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress('North','Latitude','Humidity',northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
# Out:
# The r-value is: -0.04

# %%
# Southern Hemisphere
linregress('South','Latitude','Humidity',southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
# Out:
# The r-value is: 0.13

# %% [markdown]
# **Discussion about the linear relationship:** For both southern and northern hemispheres there is negligible correlation between humidity and latitude, however, particulary in the northern hemisphere, cities that have the lowest humidity tend to have latitudes within the band of 20-50.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress('North','Latitude','Cloudiness',northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
# Out:
# The r-value is: -0.03

# %%
# Southern Hemisphere
linregress('South','Latitude','Cloudiness',southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
# Out:
# The r-value is: 0.13

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be little correlation between latitude and cloudiness for both hemispheres, however, cities with the lowest cloudiness tend to be within the band of 30-50 in the northern hemisphere and -35 to -10 in the southern hemisphere. These may be the same cities that had low humidity.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress('North','Latitude','Wind Speed',northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
# Out:
# The r-value is: 0.01

# %%
# Southern Hemisphere
linregress('South','Latitude','Wind Speed',southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
# Out:
# The r-value is: -0.2

# %% [markdown]
# **Discussion about the linear relationship:** For the northern hemisphere the seems to be little correlation between latitude and windspeed. In the southern hemisphere there seems to be a weak negative correlation between latitude and windspeed with cities experiencing the greatest wind speed typically lying south of the latitude -30.
